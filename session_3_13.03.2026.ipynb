# %%
# Session on Fri 27/02/2026
# If you want to put some packages into your local device, it's best to use Anaconda to see if they're safe
# Known packages will be fine pretty much
# You can use pypi to see if it has info on safe packages; people can report malware
# WLP hasn't used CoPilot for Python help so can't say if it's useful to say packages are safe or not
# Don't use unpublished data in GitHub

# We need code from last week for this week's session
# We imported data last week, some cleaning of the data (it'll keep cleaning again and again)
# utils folder
# Function can clean a table; separate functions help with readability and cleaning

# This week we'll look at first bits of transformation and calculation for pipeline
# Let's apply things Python gives us, but might not be things we do in practice

# How many different categories exist? E.g. how many people of every ethnicity code/primary need/in every placement type are there?
# Then we'll look at how we can find differences in time in two different columns - write into a function to make this easy - then get business/normal days etc

# Last week we ran code in the terminal rather than using run button
# This is because if you install and run in the terminal, you'll use the same Python version (run button can use a different version of Python to the terminal)

# which python - type in terminal to see version in terminal
# version for run is at top in search bar (I couldn't see it)
# Out:
# 9765625
