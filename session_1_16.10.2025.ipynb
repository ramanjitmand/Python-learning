# %%
# Session on Thu 16.10.2025


x = 5
y = 10
z = x + y
z
# Result is 5 + 10 = 15 = z

x = 12
z = x + y
z
# Result is 12(new x value) + 10 = 22 = z

x = 99
z = z + x
z
# Result is 22(from before) + 99 = 121
# I have noticed you have to keep defining z and then when you print z does it give you the correct number otherwise it keeps going back to the original x and y values??
# Out:
# 121
