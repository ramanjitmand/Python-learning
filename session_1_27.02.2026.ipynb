# %%
# Session on Fri 27/02/2026
# Assumption you have done some Python already
# Some stuff might be hard, but give it a try!
# The only way to learn Python is spending time doing projects or apply it to your work
# Over next 6 weeks we're doing 4/5 things
# Week 1 - Look at Sequel Alchemy - query databases inside Python; it'll be quick as not everyone has access to SQL
# Week 2 - Set up data processing pipeline; building and using functions already built to make pipeline; set up Python modules to bring things together
# Weeks 3-4 - Calculations done in work; how to output data for PBI or Tableu dashboarding work
# Week 5 - Writing tests for our code; not hard but not fun; you'll need to write tests if you use Python to test your code; good for interview 
# Week 6- simple dashboarding within Python
# VS Code is Microsoft's coding thing
# Today we'll use ipynb file but normally will use normal Python one (.py) after this session

# See sql_session.ipynb from now onwards - Check you can see a Python version, for me to said 'Select Kernel' so I clicked 'Python environments' then picked the one which had 'global environment' mentioned on the RHS
# Out:
# 9765625
