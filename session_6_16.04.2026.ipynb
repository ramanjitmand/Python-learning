# %%
# Session on Thu 16/04/2026
# N.B. Missed previous session which TB said was on developing apps I think as I was on A/L
# We will do dashboarding with the app 
# Only attended less than 30 mins of session so went to session on the next day, Fri 17/04/2026

# To make a webpage we need to use javascript to make the webpage; streamlit has javascript and html in backend which means you can use Python
# to make the front end
# Out:
# 9765625

# %%
# Download file here - https://github.com/data-to-insight/ERN-sessions/blob/main/data/903_xlsx.xlsx

# Click Extensions icon on LHS then type in sf-nova and install SF-nova; this is a Social Finance thing (SF is a non-profit consultancy that 
# works with children's data a lot
# sf-nova merges together ... and pyamide(?)

# ... 
# Web editor to your code is possible by changing .com to .dev in url
